# %%
import csv
import sqlite3
import pandas as pd

# %%
# Creamos la base de datos
connection = sqlite3.connect('advertising.db')

# Creamos un cursor
cursor = connection.cursor()

# %%
# create_table = '''CREATE TABLE datos(
#                 TV INTEGER NOT NULL,
#                 radio INTEGER NOT NULL,
#                 newspaper INTEGER NOT NULL,
#                 sales INTEGER NOT NULL);
#                 '''


# # Creamos la tabla dentro de nuestra base de datos
# cursor.execute(create_table)

# %%
file = open('data/Advertising.csv')

# %%
# leemos el contenido del archivo csv
contents = csv.reader(file)

# query de SQL para insertar los valores de la tabla dentro de la tabla
insert_records = "INSERT INTO datos VALUES(?, ?, ?, ?)"

cursor.executemany(insert_records, contents)

# %%
# Query de SQL para verificar los datos insertados en la tabla

borrar_encabezado_extra = "DELETE FROM datos WHERE TV = 'TV'"
rows_2 = cursor.execute(borrar_encabezado_extra).fetchall()
  
# Output to the console screen
for r in rows_2:
    print(r)
  
# Commiting the changes
connection.commit()

# %%
# Query de SQL para verificar los datos insertados en la tabla
select_all = "SELECT * FROM datos"
rows = cursor.execute(select_all).fetchall()
  
# Output to the console screen
for r in rows:
    print(r)
  
# Commiting the changes
connection.commit()
# Out:
# (230.1, 37.8, 69.2, 22100)
# (44.5, 39.3, 45.1, 10400)
# (17.2, 45.9, 69.3, 9300)
# (151.5, 41.3, 58.5, 18500)
# (180.8, 10.8, 58.4, 12900)
# (8.7, 48.9, 75, 7200)
# (57.5, 32.8, 23.5, 11800)
# (120.2, 19.6, 11.6, 13200)
# (8.6, 2.1, 1, 4800)
# (199.8, 2.6, 21.2, 10600)
# (66.1, 5.8, 24.2, 8600)
# (214.7, 24, 4, 17400)
# (23.8, 35.1, 65.9, 9200)
# (97.5, 7.6, 7.2, 9700)
# (204.1, 32.9, 46, 19000)
# (195.4, 47.7, 52.9, 22400)
# (67.8, 36.6, 114, 12500)
# (281.4, 39.6, 55.8, 24400)
# (69.2, 20.5, 18.3, 11300)
# (147.3, 23.9, 19.1, 14600)
# (218.4, 27.7, 53.4, 18000)
# (237.4, 5.1, 23.5, 12500)
# (13.2, 15.9, 49.6, 5600)
# (228.3, 16.9, 26.2, 15500)
# (62.3, 12.6, 18.3, 9700)
# (262.9, 3.5, 19.5, 12000)
# (142.9, 29.3, 12.6, 15000)
# (240.1, 16.7, 22.9, 15900)
# (248.8, 27.1, 22.9, 18900)
# (70.6, 16, 40.8, 10500)
# (292.9, 28.3, 43.2, 21400)
# (112.9, 17.4, 38.6, 11900)
# (97.2, 1.5, 30, 9600)
# (265.6, 20, 0.3, 17400)
# (95.7, 1.4, 7.4, 9500)
# (290.7, 4.1, 8.5, 12800)
# ...

# %%
connection = sqlite3.connect('advertising.db')
cursor = connection.cursor()

query = '''
INSERT INTO datos
(TV, radio, newspaper, sales)
VALUES (?,?,?,?)
'''
tv = 100
radio = 10
newspaper = 10
sales = 10000

cursor.execute(query, (tv, radio, newspaper, sales)).fetchall()
# Out:
# []

# %%
connection.commit()

# %%
def sql_query(query):

    # Ejecuta la query
    cursor.execute(query)

    # Almacena los datos de la query 
    ans = cursor.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in cursor.description]

    return pd.DataFrame(ans,columns=names)

query = '''
SELECT * 
FROM datos
'''


df = sql_query(query)
df
# Out:
#         TV  radio  newspaper    sales
# 0    230.1   37.8       69.2  22100.0
# 1     44.5   39.3       45.1  10400.0
# 2     17.2   45.9       69.3   9300.0
# 3    151.5   41.3       58.5  18500.0
# 4    180.8   10.8       58.4  12900.0
# ..     ...    ...        ...      ...
# 196   94.2    4.9        8.1   9700.0
# 197  177.0    9.3        6.4  12800.0
# 198  283.6   42.0       66.2  25500.0
# 199  232.1    8.6        8.7  13400.0
# 200  100.0   10.0       10.0  10000.0
#
# [201 rows x 4 columns]
